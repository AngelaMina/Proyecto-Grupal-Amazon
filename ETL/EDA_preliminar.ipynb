# %%
#importanto librerias a utilizar
import pandas as pd
import ast
import datetime

# %%
#creando funciones que a utilizar.


def missing_values_table(df):
    '''
    Se pasa como parametro un df de pandas, devuelve la 
    cantidad de valores NaN y a que porcentaje del total de valores corresponen
    
    
    '''
    
    mis_val = df.isna().sum()
    mis_val_percent = 100 * df.isna().sum() / len(df)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(1)
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    return mis_val_table_ren_columns



def unix_min_max(df):
    
    '''Se pasa como parametro un dataframe, imprime en pantalla la fecha mas antigua y la mas reciente utilizando la columna de unixreviewtime '''
    #Comvertimos la fecha menor a datetime 
    unix_time1 = df['unixReviewTime'].min()
    
    date_time1 = datetime.datetime.fromtimestamp(unix_time1)

    #Comvertimos la fecha mayor a datetime 
    unix_time2 = df['unixReviewTime'].max()
    
    date_time2 = datetime.datetime.fromtimestamp(unix_time2)
    
    # mostramos la fecha en unixtime
    print("Unix_Time =>",unix_time1)
    
    #mostramos le fecha comvertida
    print("Fecha y hora menor =>" ,
        date_time1.strftime('%Y-%m-%d %H:%M:%S'))


    print("----------------") 

    # mostramos la fecha en unixtime
    print("Unix_Time =>",unix_time2)
    
    #mostramos le fecha comvertida
    print("Fecha y hora mayor =>" ,
        date_time2.strftime('%Y-%m-%d %H:%M:%S'))

# %% [markdown]
# ### **Patio, Lawn and Garden**

# %%
#proceso en chunks
chunk_size = 1000

#creo lista para meter mi chrunk procesado
result_dfs = []

for chunk_df in pd.read_json("D:\Data Proyecto Indicidual\Patio_Lawn_and_Garden_5.json", lines=True, chunksize=chunk_size):
    result_dfs.append(chunk_df)

#creo df resutltante para ir concatenando mis chrunks.
patio_Lawn_df = pd.concat(result_dfs, ignore_index=True)

# %%
patio_Lawn_df
# Out:
#            reviewerID        asin
# 0      A1JZFGZEZVWQPY  B00002N674  \
# 1      A32JCI4AK2JTTG  B00002N674
# 2      A3N0P5AAMP6XD2  B00002N674
# 3       A2QK7UNJ857YG  B00002N674
# 4       AS0CYBAN6EM06  B00002N674
# ...               ...         ...
# 13267   AT53ZTTO707MB  B00KS0F4FI
# 13268   AYB4ELCS5AM8P  B00KS0F4FI
# 13269   AZMY6E8B52L2T  B00KS0F4FI
# 13270   AEC90GPFKLAAW  B00KS0F4FI
# 13271  A3LGT6UZL99IW1  B00KS0F4FI
#
#                                            reviewerName helpful
# 0                Carter H "1amazonreviewer@gmail . com"  [4, 4]  \
# 1                             Darryl Bennett "Fuzzy342"  [0, 0]
# 2                                                   H B  [2, 3]
# 3                                                 Jason  [0, 0]
# 4                                                 jimmy  [1, 1]
# ...                                                 ...     ...
# 13267                              I Do The Speed Limit  [1, 2]
# ...

# %%
missing_values_table(patio_Lawn_df)
# Out:
# Your selected dataframe has 9 columns.
# There are 1 columns that have missing values.
#               Missing Values  % of Total Values
# reviewerName             165                1.2

# %%
patio_Lawn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13272 entries, 0 to 13271
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewerID      13272 non-null  object
#  1   asin            13272 non-null  object
#  2   reviewerName    13107 non-null  object
#  3   helpful         13272 non-null  object
#  4   reviewText      13272 non-null  object
#  5   overall         13272 non-null  int64
#  6   summary         13272 non-null  object
#  7   unixReviewTime  13272 non-null  int64
#  8   reviewTime      13272 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 933.3+ KB

# %%
unix_min_max(patio_Lawn_df)
# Out:
# Unix_Time => 954892800
# Fecha y hora menor => 2000-04-04 21:00:00
# ----------------
# Unix_Time => 1405987200
# Fecha y hora mayor => 2014-07-21 21:00:00

# %% [markdown]
# ### **Pet Supplies**

# %%
#proceso en chunks
chunk_size = 1000

#creo lista para meter mi chrunk procesado
result_dfs = []

for chunk_df in pd.read_json("D:\Data Proyecto Indicidual\Pet_Supplies_5.json", lines=True, chunksize=chunk_size):
    result_dfs.append(chunk_df)

#creo df resutltante para ir concatenando mis chrunks.
pet_supplies_df = pd.concat(result_dfs, ignore_index=True)

# %%
pet_supplies_df
# Out:
#             reviewerID        asin                               reviewerName
# 0       A14CK12J7C7JRK  1223000893                         Consumer in NorCal  \
# 1       A39QHP5WLON5HV  1223000893                            Melodee Placial
# 2       A2CR37UY3VR7BN  1223000893                           Michelle Ashbery
# 3       A2A4COGL9VW2HY  1223000893                                 Michelle P
# 4       A2UBQA85NIGLHA  1223000893                      Tim  Isenhour "Timbo"
# ...                ...         ...                                        ...
# 157831  A136YD08SCJ2LV  B00KMHKOZC                         R. Spell "raspell"
# 157832  A2YKWYC3WQJX5J  B00KMHKOZC      Shannon Lastowski "Queen of Caffeine"
# 157833  A2K0D19N83G6U2  B00KMHKOZC              Spoiled Rott'n "Maria Olipas"
# 157834  A3A4ZAIBQWKOZS  B00KMHKOZC                           Stephen M. Lerch
# 157835  A1ITRGMT80D5TK  B00KMHKOZC  ThisThatNEverything "thisthatneverything"
#
# ...

# %%
missing_values_table(pet_supplies_df)
# Out:
# Your selected dataframe has 9 columns.
# There are 1 columns that have missing values.
#               Missing Values  % of Total Values
# reviewerName            1343                0.9

# %%
pet_supplies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157836 entries, 0 to 157835
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   reviewerID      157836 non-null  object
#  1   asin            157836 non-null  object
#  2   reviewerName    156493 non-null  object
#  3   helpful         157836 non-null  object
#  4   reviewText      157836 non-null  object
#  5   overall         157836 non-null  int64
#  6   summary         157836 non-null  object
#  7   unixReviewTime  157836 non-null  int64
#  8   reviewTime      157836 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 10.8+ MB

# %%
unix_min_max(pet_supplies_df)
# Out:
# Unix_Time => 1009756800
# Fecha y hora menor => 2001-12-30 21:00:00
# ----------------
# Unix_Time => 1406073600
# Fecha y hora mayor => 2014-07-22 21:00:00

# %% [markdown]
# ### **Tools and Home Improvement**

# %%
#proceso en chunks
chunk_size = 1000

#creo lista para meter mi chrunk procesado
result_dfs = []

for chunk_df in pd.read_json("D:\Data Proyecto Indicidual\Tools_and_Home_Improvement_5.json", lines=True, chunksize=chunk_size):
    result_dfs.append(chunk_df)

#creo df resutltante para ir concatenando mis chrunks.
tool_and_home_df = pd.concat(result_dfs, ignore_index=True)

# %%
tool_and_home_df
# Out:
#             reviewerID        asin                      reviewerName
# 0        A4IL0CLL27Q33  104800001X                        D. Brennan  \
# 1       A3Q5W5E7TDVLJF  104800001X                         funnyc130
# 2        A37KNOJXE2FU6  104800001X                   Joseph Yonke II
# 3       A3U4AFML9SZPWK  104800001X     Leith Tussing "I like tacos."
# 4       A36Y7X194VWVKA  104800001X                           Mark D.
# ...                ...         ...                               ...
# 134471  A1Q1Z7IR79G52A  B00LA96GLC  Ann Ingersoll Madison Rain "Ann"
# 134472  A21T5C3KL41REL  B00LA96GLC                         galbarran
# 134473  A2I8KUDXTC9WYI  B00LA96GLC                           theresa
# 134474   AAOYA0DKWED4W  B00LA96GLC                   WombatComputing
# 134475  A18JF0T0GOCORW  B00LA96GLC                       Y.Trinh "U"
#
#          helpful                                         reviewText  overall
# ...

# %%
missing_values_table(tool_and_home_df)
# Out:
# Your selected dataframe has 9 columns.
# There are 1 columns that have missing values.
#               Missing Values  % of Total Values
# reviewerName             719                0.5

# %%
tool_and_home_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134476 entries, 0 to 134475
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   reviewerID      134476 non-null  object
#  1   asin            134476 non-null  object
#  2   reviewerName    133757 non-null  object
#  3   helpful         134476 non-null  object
#  4   reviewText      134476 non-null  object
#  5   overall         134476 non-null  int64
#  6   summary         134476 non-null  object
#  7   unixReviewTime  134476 non-null  int64
#  8   reviewTime      134476 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 9.2+ MB

# %%
unix_min_max(tool_and_home_df)
# Out:
# Unix_Time => 942019200
# Fecha y hora menor => 1999-11-07 21:00:00
# ----------------
# Unix_Time => 1406073600
# Fecha y hora mayor => 2014-07-22 21:00:00

# %% [markdown]
# ### **Grocery and Gourmet Food**

# %%
#proceso en chunks
chunk_size = 1000

#creo lista para meter mi chrunk procesado
result_dfs = []

for chunk_df in pd.read_json("D:\Data Proyecto Indicidual\Grocery_and_Gourmet_Food_5.json", lines=True, chunksize=chunk_size):
    result_dfs.append(chunk_df)

#creo df resutltante para ir concatenando mis chrunks.
grocerys_df = pd.concat(result_dfs, ignore_index=True)

# %%
grocerys_df
# Out:
#             reviewerID        asin
# 0       A1VEELTKS8NLZB  616719923X  \
# 1       A14R9XMZVJ6INB  616719923X
# 2       A27IQHDZFQFNGG  616719923X
# 3       A31QY5TASILE89  616719923X
# 4       A2LWK003FFMCI5  616719923X
# ...                ...         ...
# 151249  A2L6QS8SVHT9RG  B00KCJRVO2
# 151250   AFJFXN42RZ3G2  B00KCJRVO2
# 151251   ASEBX8TBYWQWA  B00KCJRVO2
# 151252   ANKQGTXHREOI5  B00KCJRVO2
# 151253  A2CF66KIQ3RKX3  B00KCJRVO2
#
#                                             reviewerName helpful
# 0                                        Amazon Customer  [0, 0]  \
# 1                                                amf0001  [0, 1]
# 2                                                Caitlin  [3, 4]
# 3                                           DebraDownSth  [0, 0]
# 4                                               Diana X.  [1, 2]
# ...                                                  ...     ...
# 151249              randomartco "period film aficionado"  [0, 0]
# ...

# %%
missing_values_table(grocerys_df)
# Out:
# Your selected dataframe has 9 columns.
# There are 1 columns that have missing values.
#               Missing Values  % of Total Values
# reviewerName            1493                1.0

# %%
grocerys_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151254 entries, 0 to 151253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   reviewerID      151254 non-null  object
#  1   asin            151254 non-null  object
#  2   reviewerName    149761 non-null  object
#  3   helpful         151254 non-null  object
#  4   reviewText      151254 non-null  object
#  5   overall         151254 non-null  int64
#  6   summary         151254 non-null  object
#  7   unixReviewTime  151254 non-null  int64
#  8   reviewTime      151254 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 10.4+ MB

# %%
unix_min_max(grocerys_df)
# Out:
# Unix_Time => 965779200
# Fecha y hora menor => 2000-08-08 21:00:00
# ----------------
# Unix_Time => 1406073600
# Fecha y hora mayor => 2014-07-22 21:00:00

# %% [markdown]
# ### **Home and Kitchen**

# %%
#proceso en chunks
chunk_size = 1000

#creo lista para meter mi chrunk procesado
result_dfs = []

for chunk_df in pd.read_json("D:\Data Proyecto Indicidual\Home_and_Kitchen_5.json", lines=True, chunksize=chunk_size):
    result_dfs.append(chunk_df)

#creo df resutltante para ir concatenando mis chrunks.
home_and_kitchen_df = pd.concat(result_dfs, ignore_index=True)

# %%
home_and_kitchen_df
# Out:
#             reviewerID        asin            reviewerName   helpful
# 0        APYOBQE6M18AA  0615391206         Martin Schwartz    [0, 0]  \
# 1       A1JVQTAGHYOL7F  0615391206           Michelle Dinh    [0, 0]
# 2       A3UPYGJKZ0XTU4  0615391206            mirasreviews  [26, 27]
# 3       A2MHCTX43MIMDZ  0615391206  M. Johnson "Tea Lover"  [14, 18]
# 4        AHAI85T5C2DH3  0615391206                PugLover    [0, 0]
# ...                ...         ...                     ...       ...
# 551677  A11J1FHCK5U06J  B00LBFUU12            Karinna Ball    [0, 0]
# 551678   A537XC69FAD3J  B00LBFUU12                 L Green    [0, 0]
# 551679   AWHZOUIQ0VO7M  B00LBFUU12               Richard N    [0, 0]
# 551680  A1KQNP8MOJDJKC  B00LBFUU12                      RS    [1, 1]
# 551681  A3AHOSISKNBLZ6  B00LBFUU12                 Tonya S    [0, 0]
#
#                                                reviewText  overall
# 0       My daughter wanted this book and the price on ...        5  \
# ...

# %%
missing_values_table(home_and_kitchen_df)
# Out:
# Your selected dataframe has 9 columns.
# There are 1 columns that have missing values.
#               Missing Values  % of Total Values
# reviewerName            4953                0.9

# %%
home_and_kitchen_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551682 entries, 0 to 551681
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   reviewerID      551682 non-null  object
#  1   asin            551682 non-null  object
#  2   reviewerName    546729 non-null  object
#  3   helpful         551682 non-null  object
#  4   reviewText      551682 non-null  object
#  5   overall         551682 non-null  int64
#  6   summary         551682 non-null  object
#  7   unixReviewTime  551682 non-null  int64
#  8   reviewTime      551682 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 37.9+ MB

# %%
unix_min_max(home_and_kitchen_df)
# Out:
# Unix_Time => 965779200
# Fecha y hora menor => 2000-08-08 21:00:00
# ----------------
# Unix_Time => 1406073600
# Fecha y hora mayor => 2014-07-22 21:00:00

# %% [markdown]
# ##### Todos los dataframes tienen las mismas caracteristicas, para analizar los valores nulos que encontramos en la columna 'reviewerID' solo utilizare uno de ellos, en este caso 'tool_and_home_df'

# %%
tool_and_home_df[tool_and_home_df["reviewerName"].isna()]
# Out:
#             reviewerID        asin reviewerName  helpful
# 21      A3NGABXDIB0POU  1933622709          NaN   [0, 0]  \
# 140     A3GFEC3CFRS5NN  B0000222V9          NaN   [0, 0]
# 173     A3GFEC3CFRS5NN  B0000222VF          NaN   [0, 0]
# 1020    A2K9C4B7O22HHL  B0000223GD          NaN   [5, 5]
# 1527     AY11MCGDJ6MR6  B0000223OY          NaN   [0, 0]
# ...                ...         ...          ...      ...
# 127127  A1D3TL21VKWBPD  B00B2F3KDQ          NaN   [0, 0]
# 127128   AMDX36E9A3EK9  B00B2F3KDQ          NaN   [0, 1]
# 127129  A3NCSQ3UE9X7U5  B00B2F3KDQ          NaN   [2, 4]
# 128138  A32D51AGXQWZ1E  B00BLJ3AR4          NaN   [1, 9]
# 131779  A32D51AGXQWZ1E  B00F9TE06M          NaN  [7, 21]
#
#                                                reviewText  overall
# 21                        Awesome to light an entire room        5  \
# 140     This is an important item to have with a plung...        3
# 173     Not much to say, well made for the most part, ...        4
# ...

# %%
tool_and_home_df[tool_and_home_df.duplicated(subset=["reviewText", "unixReviewTime", "reviewTime", "summary","reviewerName"])]
# Out:
# Empty DataFrame
# Columns: [reviewerID, asin, reviewerName, helpful, reviewText, overall, summary, unixReviewTime, reviewTime]
# Index: []

# %%
lineas = []

with open("D:\Data Proyecto Indicidual\metadata.json", encoding='utf-8') as f:
    for line in f:
        lineas.append(ast.literal_eval(line))
        if len(lineas) == 500000:
            break

metadata = pd.DataFrame(lineas)

# %%
metadata
# Out:
#               asin                  salesRank
# 0       0001048791         {'Books': 6334800}  \
# 1       0000143561    {'Movies & TV': 376041}
# 2       0000037214      {'Clothing': 1233557}
# 3       0000032069                        NaN
# 4       0000031909   {'Toys & Games': 201847}
# ...            ...                        ...
# 499995  0735322112  {'Toys & Games': 1257666}
# 499996  0735319146         {'Books': 9638810}
# 499997  0735203237         {'Books': 1735579}
# 499998  0735316376                        NaN
# 499999  0735326541   {'Toys & Games': 152965}
#
#                                                     imUrl
# 0       http://ecx.images-amazon.com/images/I/51MKP0T4...  \
# 1       http://g-ecx.images-amazon.com/images/G/01/x-s...
# 2       http://ecx.images-amazon.com/images/I/31mCncNu...
# 3       http://ecx.images-amazon.com/images/I/51EzU6qu...
# 4       http://ecx.images-amazon.com/images/I/41xBoP0F...
# ...

# %%
missing_values_table(metadata)
# Out:
# Your selected dataframe has 9 columns.
# There are 8 columns that have missing values.
#              Missing Values  % of Total Values
# brand                499619               99.9
# description          172382               34.5
# related              118391               23.7
# price                116247               23.2
# imUrl                  9297                1.9
# salesRank              4569                0.9
# title                   535                0.1
# categories              196                0.0
